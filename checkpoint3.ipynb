# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import seaborn as sns
import h5py
from keras import layers
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop

import pydot
from IPython.display import SVG


import keras.backend as K
K.set_image_data_format('channels_last')
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %%
def load_dataset(path_to_train, path_to_test):
    train_dataset = h5py.File(path_to_train)
    train_x = np.array(train_dataset['train_set_x'][:])
    train_y = np.array(train_dataset['train_set_y'][:])

    test_dataset = h5py.File(path_to_test)
    test_x = np.array(test_dataset['test_set_x'][:])
    test_y = np.array(test_dataset['test_set_y'][:])

    # y reshaped
    train_y = train_y.reshape((1, train_x.shape[0]))
    test_y = test_y.reshape((1, test_y.shape[0]))

    return train_x, train_y, test_x, test_y

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig = load_dataset("train_happy.h5","test_happy.h5")

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
# Sample image from dataset
print("Image shape :",X_train_orig[10].shape)
imshow(X_train_orig[9])
print(Y_test[9])
# Out:
# Image shape : (64, 64, 3)
# [0]

# %%
from keras.layers import Conv2D, Dense, MaxPool2D, Flatten, Dropout, Activation

model = Sequential()
#Conv layer 1
model.add(Conv2D(filters=20, kernel_size = (3, 3), padding = "same", strides=(1,2), input_shape=(64, 64, 3),activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

#Conv layer 2
model.add(Conv2D(filters=20, kernel_size = (3, 3), padding = "same", strides=(1,2),activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

#Flatten layer
model.add(Flatten())

#Fully connected layers
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 64, activation='relu'))
model.add(Dropout(0.2))

#output layer
model.add(Dense(units = 1, activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 32, 20)        560
#
#  max_pooling2d (MaxPooling2D  (None, 32, 16, 20)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 8, 20)         3620
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 4, 20)        0
#  2D)
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense_6 (Dense)             (None, 64)                81984
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 90,389
# Trainable params: 90,389
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=RMSprop(), loss='binary_crossentropy', metrics=["accuracy"])
history = model.fit(X_train,
                    Y_train,
                    batch_size=10,
                    epochs=50,
                    verbose=1,
                    validation_split=0.2)
# Out:
# Epoch 1/50
# 48/48 [==============================] - 2s 27ms/step - loss: 0.6975 - accuracy: 0.5104 - val_loss: 0.6710 - val_accuracy: 0.5417
# Epoch 2/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.6467 - accuracy: 0.6625 - val_loss: 0.5614 - val_accuracy: 0.8083
# Epoch 3/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.5319 - accuracy: 0.7500 - val_loss: 0.3678 - val_accuracy: 0.9167
# Epoch 4/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.4073 - accuracy: 0.7937 - val_loss: 0.3206 - val_accuracy: 0.8917
# Epoch 5/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.2992 - accuracy: 0.8771 - val_loss: 0.4563 - val_accuracy: 0.7333
# Epoch 6/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.2378 - accuracy: 0.8958 - val_loss: 0.1955 - val_accuracy: 0.9167
# Epoch 7/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.1868 - accuracy: 0.9333 - val_loss: 0.2850 - val_accuracy: 0.8500
# Epoch 8/50
# 48/48 [==============================] - 2s 33ms/step - loss: 0.1670 - accuracy: 0.9458 - val_loss: 0.0922 - val_accuracy: 0.9667
# Epoch 9/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.1640 - accuracy: 0.9354 - val_loss: 0.1277 - val_accuracy: 0.9583
# Epoch 10/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.1410 - accuracy: 0.9521 - val_loss: 0.0826 - val_accuracy: 0.9583
# Epoch 11/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.1192 - accuracy: 0.9604 - val_loss: 0.0897 - val_accuracy: 0.9667
# Epoch 12/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.1042 - accuracy: 0.9646 - val_loss: 0.0565 - val_accuracy: 0.9833
# Epoch 13/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0779 - accuracy: 0.9771 - val_loss: 0.0618 - val_accuracy: 0.9833
# Epoch 14/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0799 - accuracy: 0.9625 - val_loss: 0.1980 - val_accuracy: 0.9000
# Epoch 15/50
# 48/48 [==============================] - 2s 33ms/step - loss: 0.0649 - accuracy: 0.9771 - val_loss: 0.0491 - val_accuracy: 0.9833
# Epoch 16/50
# 48/48 [==============================] - 2s 46ms/step - loss: 0.1069 - accuracy: 0.9625 - val_loss: 0.0578 - val_accuracy: 0.9833
# Epoch 17/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0525 - accuracy: 0.9833 - val_loss: 0.1554 - val_accuracy: 0.9250
# Epoch 18/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0567 - accuracy: 0.9833 - val_loss: 0.0668 - val_accuracy: 0.9750
# Epoch 19/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0457 - accuracy: 0.9833 - val_loss: 0.0207 - val_accuracy: 0.9917
# Epoch 20/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0678 - accuracy: 0.9792 - val_loss: 0.0816 - val_accuracy: 0.9500
# Epoch 21/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0456 - accuracy: 0.9875 - val_loss: 0.0255 - val_accuracy: 0.9917
# Epoch 22/50
# 48/48 [==============================] - 1s 22ms/step - loss: 0.0688 - accuracy: 0.9771 - val_loss: 0.0362 - val_accuracy: 0.9917
# Epoch 23/50
# 48/48 [==============================] - 1s 29ms/step - loss: 0.0493 - accuracy: 0.9792 - val_loss: 0.0565 - val_accuracy: 0.9833
# Epoch 24/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0286 - accuracy: 0.9854 - val_loss: 0.0517 - val_accuracy: 0.9833
# Epoch 25/50
# 48/48 [==============================] - 2s 50ms/step - loss: 0.0446 - accuracy: 0.9812 - val_loss: 0.0373 - val_accuracy: 0.9917
# Epoch 26/50
# 48/48 [==============================] - 2s 41ms/step - loss: 0.0348 - accuracy: 0.9854 - val_loss: 0.0427 - val_accuracy: 0.9833
# Epoch 27/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0248 - accuracy: 0.9917 - val_loss: 0.0641 - val_accuracy: 0.9833
# Epoch 28/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0281 - accuracy: 0.9833 - val_loss: 0.0681 - val_accuracy: 0.9750
# Epoch 29/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0456 - accuracy: 0.9812 - val_loss: 0.0679 - val_accuracy: 0.9750
# Epoch 30/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.1657 - val_accuracy: 0.9667
# Epoch 31/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0310 - accuracy: 0.9896 - val_loss: 0.0845 - val_accuracy: 0.9750
# Epoch 32/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0299 - accuracy: 0.9937 - val_loss: 0.0783 - val_accuracy: 0.9833
# Epoch 33/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0196 - accuracy: 0.9896 - val_loss: 0.0281 - val_accuracy: 0.9833
# Epoch 34/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0236 - accuracy: 0.9875 - val_loss: 0.0233 - val_accuracy: 0.9917
# Epoch 35/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0243 - accuracy: 0.9896 - val_loss: 0.0269 - val_accuracy: 0.9833
# Epoch 36/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0329 - accuracy: 0.9875 - val_loss: 0.0425 - val_accuracy: 0.9917
# Epoch 37/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0251 - accuracy: 0.9937 - val_loss: 0.0781 - val_accuracy: 0.9833
# Epoch 38/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0391 - accuracy: 0.9875 - val_loss: 0.0119 - val_accuracy: 1.0000
# Epoch 39/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0098 - accuracy: 0.9958 - val_loss: 0.0315 - val_accuracy: 0.9917
# Epoch 40/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0364 - accuracy: 0.9896 - val_loss: 0.0427 - val_accuracy: 0.9917
# Epoch 41/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0357 - accuracy: 0.9937 - val_loss: 0.0458 - val_accuracy: 0.9833
# Epoch 42/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0167 - accuracy: 0.9979 - val_loss: 0.0505 - val_accuracy: 0.9750
# Epoch 43/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0273 - accuracy: 0.9958 - val_loss: 0.0540 - val_accuracy: 0.9750
# Epoch 44/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0064 - accuracy: 0.9958 - val_loss: 0.0147 - val_accuracy: 0.9917
# Epoch 45/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0396 - accuracy: 0.9917 - val_loss: 0.0243 - val_accuracy: 0.9833
# Epoch 46/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0173 - accuracy: 0.9958 - val_loss: 0.0949 - val_accuracy: 0.9833
# Epoch 47/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0258 - accuracy: 0.9958 - val_loss: 0.0254 - val_accuracy: 0.9833
# Epoch 48/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0209 - accuracy: 0.9958 - val_loss: 0.0602 - val_accuracy: 0.9750
# Epoch 49/50
# 48/48 [==============================] - 1s 23ms/step - loss: 0.0220 - accuracy: 0.9875 - val_loss: 0.0549 - val_accuracy: 0.9750
# Epoch 50/50
# 48/48 [==============================] - 1s 24ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.0316 - val_accuracy: 0.9917

# %%
train_accuracy = history.history['val_accuracy']
train_loss = history.history['val_loss']

count = range(len(train_accuracy))
plt.plot(count, train_accuracy, label='Training accuracy')
plt.plot(count, train_loss, label='Training Loss')
plt.title('epochs vs Training Loss')
plt.legend()

# %%
score = model.evaluate(X_test, Y_test, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.9800000190734863

# %%
pred = model.predict(X_test)
predictions = [float(np.round(x)) for x in pred]
# Out:
# 5/5 [==============================] - 0s 21ms/step

# %%
from sklearn.metrics import f1_score, classification_report,confusion_matrix, ConfusionMatrixDisplay
def conf_matrix(y_test, y_pred, model):
    cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
    fig, ax = plt.subplots(figsize=(15,12))
    disp.plot(ax=ax)
    plt.show()
conf_matrix(Y_test, predictions, model)

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="sgd", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adadelta", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adagrad", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Adamax", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Nadam", loss='binary_crossentropy', metrics=["accuracy"])
model.compile(optimizer="Ftrl", loss='binary_crossentropy', metrics=["accuracy"])
text_labels = ["Sad", "Happy"]

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 150)
    plt.imshow(X_test_orig[img_index], cmap=plt.cm.gray)
    actual_label  = Y_test[img_index][0]
    predicted_label = int(predictions[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
